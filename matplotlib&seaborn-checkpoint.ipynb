# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('mpg')
df.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %%
df.tail(2)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year origin         name
# 396          82    usa  ford ranger
# 397          82    usa   chevy s-10

# %%
df.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower       True
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df[df['horsepower'].isna()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# # UNIVARIATE FOR NUMERICAL
# 1.HISTOGRAM
#
# 2.KDE
#
# 3.DIST
#
# 4.BOX
#
# 5.VIOLIN

# %%
sns.histplot(x=df['acceleration'])
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='Count'>

# %%
sns.kdeplot(x=df['acceleration'])
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='Density'>

# %%
sns.distplot(x=df['mpg'])
# Out:
# C:\Users\crisr\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxplot(x=df['displacement'])
# Out:
# <AxesSubplot:xlabel='displacement'>

# %%
sns.violinplot(x=df['mpg'])
# Out:
# <AxesSubplot:xlabel='mpg'>

# %% [markdown]
# # UNIVARIATE FOR NON-NUMERICAL

# %%
sns.countplot(x=df['origin'])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %%
df['origin'].value_counts().plot(kind='pie', autopct='%1.2f%%')
# Out:
# <AxesSubplot:ylabel='origin'>

# %%
df['origin'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # BIVARIATE FOR NUM VS NON NUM

# %% [markdown]
# ## STRIP, SWARM, BOX, VIOLIN

# %%
df.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %%
sns.stripplot(x=df['origin'],y=df['acceleration'])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
sns.swarmplot(x=df['origin'],y=df['acceleration'])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
sns.violinplot(x=df['origin'],y=df['acceleration'])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %%
sns.boxplot(x=df['origin'],y=df['acceleration'])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='acceleration'>

# %% [markdown]
# # BIVARIATE FOR NUM VS NUM

# %%
sns.scatterplot(y=df['horsepower'], x=df['weight'])
# Out:
# <AxesSubplot:xlabel='weight', ylabel='horsepower'>

# %% [markdown]
# # BIVARIATE FOR NON-NUM VS NON-NUM

# %%
import pandas as pd
pd.crosstab(df['origin'],df['name']).plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='origin'>

# %% [markdown]
# # MULTIVARIATE

# %%
sns.pairplot(df)
